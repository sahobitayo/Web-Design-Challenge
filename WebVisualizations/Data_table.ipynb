# %%
import pandas as pd

# %%
# Read the csv file in pandas
cities_table = pd.read_csv("Resources\Cities.csv")

# %%
#setting up city are the index

cities_table = cities_table.set_index('City')


cities_table.head()
# Out:
#               City_ID  Cloudiness Country        Date  Humidity    Lat  \
# City
# jacareacanga        0           0      BR  1528902000        62  -6.22
# kaitangata          1         100      NZ  1528905304        94 -46.28
# goulburn            2          20      AU  1528905078        91 -34.75
# lata                3          76      IN  1528905305        89  30.78
# chokurdakh          4           0      RU  1528905306        88  70.62
#
#                  Lng  Max Temp  Wind Speed
# City
# jacareacanga  -57.76     89.60        6.93
# kaitangata    169.85     42.61        5.64
# goulburn      149.72     44.32       10.11
# lata           78.62     59.89        0.94
# chokurdakh    147.90     32.17        2.95

# %%
# to save as table html file 

cities_table.to_html("table.html")

# %%
# assign it to a  variable (string) 
html_file = cities_table.to_html()

# %%
#show the html file
print(html_file)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City_ID</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#     <tr>
#       <th>City</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>jacareacanga</th>
#       <td>0</td>
#       <td>0</td>
#       <td>BR</td>
#       <td>1528902000</td>
#       <td>62</td>
#       <td>-6.22</td>
#       <td>-57.76</td>
#       <td>89.60</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <th>kaitangata</th>
#       <td>1</td>
#       <td>100</td>
#       <td>NZ</td>
#       <td>1528905304</td>
#       <td>94</td>
#       <td>-46.28</td>
# ...
